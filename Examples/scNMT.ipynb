# %%
from unioncom import UnionCom
import numpy as np
import unioncom
from sklearn import preprocessing

# %%
data1 = np.loadtxt("./scNMT/Paccessibility_300.txt")
data2 = np.loadtxt("./scNMT/Pmethylation_300.txt")
data3 = np.loadtxt("./scNMT/RNA_300.txt")
type1 = np.loadtxt("./scNMT/type1.txt")
type2 = np.loadtxt("./scNMT/type2.txt")
type3 = np.loadtxt("./scNMT/type3.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
type3 = type3.astype(np.int)
not_connected, connect_element, index = unioncom.utils.Maximum_connected_subgraph(data3, kmax=40)
if not_connected:
	data3 = data3[connect_element[index]]
	type3 = type3[connect_element[index]]
min_max_scaler = preprocessing.MinMaxScaler()
data3 = min_max_scaler.fit_transform(data3)
print(np.shape(data3))
# Out:
# (1773, 300)

# %%
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (612, 300)
# Dataset 1: (709, 300)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:0.9806 alpha:1.6397
# epoch:[2000/20000] err:0.9565 alpha:1.6337
# epoch:[3000/20000] err:0.9098 alpha:1.6522
# epoch:[4000/20000] err:0.7979 alpha:1.6889
# epoch:[5000/20000] err:0.7140 alpha:1.7217
# epoch:[6000/20000] err:0.5984 alpha:1.7542
# epoch:[7000/20000] err:0.4919 alpha:1.7838
# epoch:[8000/20000] err:0.4367 alpha:1.8039
# epoch:[9000/20000] err:0.6005 alpha:1.7732
# epoch:[10000/20000] err:0.5955 alpha:1.7721
# epoch:[11000/20000] err:0.6276 alpha:1.7639
# epoch:[12000/20000] err:0.6602 alpha:1.7581
# epoch:[13000/20000] err:0.6553 alpha:1.7631
# epoch:[14000/20000] err:0.6699 alpha:1.7599
# epoch:[15000/20000] err:0.6599 alpha:1.7643
# epoch:[16000/20000] err:0.6649 alpha:1.7643
# epoch:[17000/20000] err:0.6682 alpha:1.7656
# epoch:[18000/20000] err:0.6611 alpha:1.7707
# epoch:[19000/20000] err:0.6776 alpha:1.7670
# epoch:[20000/20000] err:0.6899 alpha:1.7638
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:3.149358, align_loss:0.195105
# epoch:[100/200]: loss:3.074262, align_loss:0.185426
# epoch:[150/200]: loss:2.553926, align_loss:0.194841
# epoch:[200/200]: loss:2.344060, align_loss:0.191482
# Done
# ---------------------------------
# unionCom Done!
# time: 91.16342806816101 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# label transfer accuracy of data1:
# 0.8594771241830066
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2,data3])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (612, 300)
# Dataset 1: (709, 300)
# Dataset 2: (1773, 300)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 3
# use device: cuda:0
# epoch:[1000/20000] err:1.5593 alpha:6.5002
# epoch:[2000/20000] err:1.2728 alpha:5.8881
# epoch:[3000/20000] err:1.0367 alpha:6.1534
# epoch:[4000/20000] err:0.8668 alpha:6.3650
# epoch:[5000/20000] err:0.7145 alpha:6.5239
# epoch:[6000/20000] err:0.6318 alpha:6.6380
# epoch:[7000/20000] err:0.5893 alpha:6.7221
# epoch:[8000/20000] err:0.5644 alpha:6.7890
# epoch:[9000/20000] err:0.5484 alpha:6.8460
# epoch:[10000/20000] err:0.7218 alpha:6.7955
# epoch:[11000/20000] err:0.7568 alpha:6.8633
# epoch:[12000/20000] err:0.7772 alpha:6.8431
# epoch:[13000/20000] err:0.7825 alpha:6.8872
# epoch:[14000/20000] err:0.7826 alpha:6.8829
# epoch:[15000/20000] err:0.8014 alpha:6.9042
# epoch:[16000/20000] err:0.7987 alpha:6.9287
# epoch:[17000/20000] err:0.8007 alpha:6.9461
# epoch:[18000/20000] err:0.7981 alpha:6.9706
# epoch:[19000/20000] err:0.8056 alpha:6.9803
# epoch:[20000/20000] err:0.8098 alpha:6.9826
# ---------------------------------
# Find correspondence between Dataset 2 and Dataset 3
# use device: cuda:0
# epoch:[1000/20000] err:1.8177 alpha:3.2772
# epoch:[2000/20000] err:1.4782 alpha:3.0957
# epoch:[3000/20000] err:1.2395 alpha:3.2328
# epoch:[4000/20000] err:1.0885 alpha:3.3311
# epoch:[5000/20000] err:0.9296 alpha:3.4051
# epoch:[6000/20000] err:0.8304 alpha:3.4595
# epoch:[7000/20000] err:0.7774 alpha:3.5009
# epoch:[8000/20000] err:0.7474 alpha:3.5341
# epoch:[9000/20000] err:0.7291 alpha:3.5616
# epoch:[10000/20000] err:0.8875 alpha:3.5430
# epoch:[11000/20000] err:0.9314 alpha:3.5700
# epoch:[12000/20000] err:0.9372 alpha:3.5696
# epoch:[13000/20000] err:0.9582 alpha:3.5806
# epoch:[14000/20000] err:0.9736 alpha:3.5916
# epoch:[15000/20000] err:0.9799 alpha:3.6039
# epoch:[16000/20000] err:0.9814 alpha:3.6048
# epoch:[17000/20000] err:0.9810 alpha:3.6119
# epoch:[18000/20000] err:0.9845 alpha:3.6242
# epoch:[19000/20000] err:0.9810 alpha:3.6266
# epoch:[20000/20000] err:0.9884 alpha:3.6298
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:4.973272, align_loss:0.494188
# epoch:[100/200]: loss:4.349391, align_loss:0.438768
# epoch:[150/200]: loss:4.498218, align_loss:0.417428
# epoch:[200/200]: loss:4.541138, align_loss:0.376253
# Done
# ---------------------------------
# unionCom Done!
# time: 389.7458288669586 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2,type3])
uc.Visualize([data1,data2,data3], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2,data3], integrated_data, [type1,type2,type3], mode='PCA') # with datatype
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# label transfer accuracy of data1:
# 0.8006535947712419
# label transfer accuracy of data2:
# 0.8533145275035261
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
