# %%
from unioncom import UnionCom
import numpy as np
data1 = np.loadtxt("./MMD/s1_mapped1.txt")
data2 = np.loadtxt("./MMD/s1_mapped2.txt")
type1 = np.loadtxt("./MMD/s1_type1.txt")
type2 = np.loadtxt("./MMD/s1_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:3.1091 alpha:0.6239
# epoch:[2000/20000] err:2.1241 alpha:0.6907
# epoch:[3000/20000] err:1.4319 alpha:0.7402
# epoch:[4000/20000] err:1.1562 alpha:0.7610
# epoch:[5000/20000] err:1.0398 alpha:0.7697
# epoch:[6000/20000] err:0.9694 alpha:0.7744
# epoch:[7000/20000] err:0.9224 alpha:0.7775
# epoch:[8000/20000] err:0.8934 alpha:0.7797
# epoch:[9000/20000] err:0.8750 alpha:0.7813
# epoch:[10000/20000] err:0.8626 alpha:0.7826
# epoch:[11000/20000] err:0.8580 alpha:0.7833
# epoch:[12000/20000] err:0.8581 alpha:0.7835
# epoch:[13000/20000] err:0.8591 alpha:0.7841
# epoch:[14000/20000] err:0.8577 alpha:0.7847
# epoch:[15000/20000] err:0.8570 alpha:0.7848
# epoch:[16000/20000] err:0.8590 alpha:0.7850
# epoch:[17000/20000] err:0.8570 alpha:0.7855
# epoch:[18000/20000] err:0.8586 alpha:0.7854
# epoch:[19000/20000] err:0.8578 alpha:0.7859
# epoch:[20000/20000] err:0.8593 alpha:0.7857
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:2.022953, align_loss:0.317788
# epoch:[100/200]: loss:1.838054, align_loss:0.203977
# epoch:[150/200]: loss:1.810459, align_loss:0.232402
# epoch:[200/200]: loss:1.704286, align_loss:0.197441
# Done
# ---------------------------------
# unionCom Done!
# time: 57.17387056350708 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# label transfer accuracy of data1:
# 0.94
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
data1 = np.loadtxt("./MMD/s2_mapped1.txt")
data2 = np.loadtxt("./MMD/s2_mapped2.txt")
type1 = np.loadtxt("./MMD/s2_type1.txt")
type2 = np.loadtxt("./MMD/s2_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:1.4099 alpha:0.4501
# epoch:[2000/20000] err:1.1973 alpha:0.4858
# epoch:[3000/20000] err:0.8220 alpha:0.5285
# epoch:[4000/20000] err:0.5612 alpha:0.5599
# epoch:[5000/20000] err:0.4165 alpha:0.5774
# epoch:[6000/20000] err:0.3304 alpha:0.5871
# epoch:[7000/20000] err:0.2825 alpha:0.5928
# epoch:[8000/20000] err:0.2517 alpha:0.5965
# epoch:[9000/20000] err:0.2289 alpha:0.5993
# epoch:[10000/20000] err:0.2759 alpha:0.5936
# epoch:[11000/20000] err:0.2799 alpha:0.5936
# epoch:[12000/20000] err:0.2847 alpha:0.5931
# epoch:[13000/20000] err:0.2860 alpha:0.5936
# epoch:[14000/20000] err:0.2849 alpha:0.5937
# epoch:[15000/20000] err:0.2869 alpha:0.5941
# epoch:[16000/20000] err:0.2802 alpha:0.5951
# epoch:[17000/20000] err:0.2839 alpha:0.5946
# epoch:[18000/20000] err:0.2857 alpha:0.5945
# epoch:[19000/20000] err:0.2842 alpha:0.5948
# epoch:[20000/20000] err:0.2927 alpha:0.5942
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:1.547194, align_loss:0.130074
# epoch:[100/200]: loss:1.762664, align_loss:0.100669
# epoch:[150/200]: loss:1.429978, align_loss:0.102372
# epoch:[200/200]: loss:1.462065, align_loss:0.096491
# Done
# ---------------------------------
# unionCom Done!
# time: 57.18780970573425 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# label transfer accuracy of data1:
# 0.9833333333333333
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
data1 = np.loadtxt("./MMD/s3_mapped1.txt")
data2 = np.loadtxt("./MMD/s3_mapped2.txt")
type1 = np.loadtxt("./MMD/s3_type1.txt")
type2 = np.loadtxt("./MMD/s3_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:7.2326 alpha:0.4408
# epoch:[2000/20000] err:4.2418 alpha:0.5663
# epoch:[3000/20000] err:2.4367 alpha:0.6310
# epoch:[4000/20000] err:1.7389 alpha:0.6556
# epoch:[5000/20000] err:1.4793 alpha:0.6643
# epoch:[6000/20000] err:1.3698 alpha:0.6677
# epoch:[7000/20000] err:1.3209 alpha:0.6692
# epoch:[8000/20000] err:1.3001 alpha:0.6700
# epoch:[9000/20000] err:1.2922 alpha:0.6704
# epoch:[10000/20000] err:1.2901 alpha:0.6707
# epoch:[11000/20000] err:1.2919 alpha:0.6709
# epoch:[12000/20000] err:1.2975 alpha:0.6708
# epoch:[13000/20000] err:1.3058 alpha:0.6709
# epoch:[14000/20000] err:1.3135 alpha:0.6711
# epoch:[15000/20000] err:1.3170 alpha:0.6710
# epoch:[16000/20000] err:1.3224 alpha:0.6711
# epoch:[17000/20000] err:1.3262 alpha:0.6711
# epoch:[18000/20000] err:1.3332 alpha:0.6713
# epoch:[19000/20000] err:1.3380 alpha:0.6710
# epoch:[20000/20000] err:1.3396 alpha:0.6713
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:1.588326, align_loss:0.202017
# epoch:[100/200]: loss:1.597124, align_loss:0.204311
# epoch:[150/200]: loss:1.573349, align_loss:0.192281
# epoch:[200/200]: loss:1.410101, align_loss:0.181158
# Done
# ---------------------------------
# unionCom Done!
# time: 57.4192910194397 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# label transfer accuracy of data1:
# 0.9433333333333334
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
