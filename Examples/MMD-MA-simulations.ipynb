# %%
from unioncom import UnionCom
import numpy as np
data1 = np.loadtxt("../MMD/s1_mapped1.txt")
data2 = np.loadtxt("../MMD/s1_mapped2.txt")
type1 = np.loadtxt("../MMD/s1_type1.txt")
type2 = np.loadtxt("../MMD/s1_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[100/2000] err:4.6418 alpha:0.7917
# epoch:[200/2000] err:2.8181 alpha:0.5136
# epoch:[300/2000] err:2.7333 alpha:0.5463
# epoch:[400/2000] err:2.4588 alpha:0.5762
# epoch:[500/2000] err:1.9198 alpha:0.6215
# epoch:[600/2000] err:1.6833 alpha:0.6524
# epoch:[700/2000] err:1.5814 alpha:0.6707
# epoch:[800/2000] err:1.4764 alpha:0.6849
# epoch:[900/2000] err:1.3172 alpha:0.6995
# epoch:[1000/2000] err:1.2079 alpha:0.7119
# epoch:[1100/2000] err:1.1566 alpha:0.7208
# epoch:[1200/2000] err:1.1285 alpha:0.7276
# epoch:[1300/2000] err:1.1097 alpha:0.7333
# epoch:[1400/2000] err:1.0953 alpha:0.7383
# epoch:[1500/2000] err:1.0836 alpha:0.7427
# epoch:[1600/2000] err:1.0734 alpha:0.7467
# epoch:[1700/2000] err:1.0645 alpha:0.7503
# epoch:[1800/2000] err:1.0564 alpha:0.7536
# epoch:[1900/2000] err:1.0489 alpha:0.7565
# epoch:[2000/2000] err:1.0416 alpha:0.7592
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:1.181636, align_loss:0.097179
# epoch:[20/100]: loss:1.016288, align_loss:0.095241
# epoch:[30/100]: loss:0.965497, align_loss:0.085706
# epoch:[40/100]: loss:0.936379, align_loss:0.097109
# epoch:[50/100]: loss:0.886532, align_loss:0.084423
# epoch:[60/100]: loss:0.813726, align_loss:0.104259
# epoch:[70/100]: loss:0.822624, align_loss:0.078366
# epoch:[80/100]: loss:0.773638, align_loss:0.085618
# epoch:[90/100]: loss:0.841854, align_loss:0.089273
# epoch:[100/100]: loss:0.832921, align_loss:0.074454
# Done
# ---------------------------------
# unionCom Done!
# time: 10.309704065322876 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# label transfer accuracy of data1:
# 0.9233333333333333
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
data1 = np.loadtxt("../MMD/s2_mapped1.txt")
data2 = np.loadtxt("../MMD/s2_mapped2.txt")
type1 = np.loadtxt("../MMD/s2_type1.txt")
type2 = np.loadtxt("../MMD/s2_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[100/2000] err:2.0706 alpha:0.5480
# epoch:[200/2000] err:1.2981 alpha:0.3596
# epoch:[300/2000] err:1.2666 alpha:0.3836
# epoch:[400/2000] err:1.2142 alpha:0.4039
# epoch:[500/2000] err:1.1678 alpha:0.4219
# epoch:[600/2000] err:1.1363 alpha:0.4368
# epoch:[700/2000] err:1.1091 alpha:0.4493
# epoch:[800/2000] err:1.0629 alpha:0.4613
# epoch:[900/2000] err:0.9676 alpha:0.4755
# epoch:[1000/2000] err:0.8317 alpha:0.4925
# epoch:[1100/2000] err:0.7205 alpha:0.5083
# epoch:[1200/2000] err:0.6506 alpha:0.5205
# epoch:[1300/2000] err:0.6046 alpha:0.5298
# epoch:[1400/2000] err:0.5707 alpha:0.5372
# epoch:[1500/2000] err:0.5437 alpha:0.5434
# epoch:[1600/2000] err:0.5208 alpha:0.5488
# epoch:[1700/2000] err:0.5007 alpha:0.5535
# epoch:[1800/2000] err:0.4825 alpha:0.5577
# epoch:[1900/2000] err:0.4655 alpha:0.5615
# epoch:[2000/2000] err:0.4497 alpha:0.5650
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:0.902028, align_loss:0.056281
# epoch:[20/100]: loss:0.838606, align_loss:0.045044
# epoch:[30/100]: loss:0.849457, align_loss:0.055478
# epoch:[40/100]: loss:0.702514, align_loss:0.043436
# epoch:[50/100]: loss:0.682414, align_loss:0.034667
# epoch:[60/100]: loss:0.658213, align_loss:0.036888
# epoch:[70/100]: loss:0.662472, align_loss:0.040491
# epoch:[80/100]: loss:0.691082, align_loss:0.048935
# epoch:[90/100]: loss:0.625526, align_loss:0.036900
# epoch:[100/100]: loss:0.696428, align_loss:0.041125
# Done
# ---------------------------------
# unionCom Done!
# time: 9.862696886062622 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# label transfer accuracy of data1:
# 0.9833333333333333
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
data1 = np.loadtxt("../MMD/s3_mapped1.txt")
data2 = np.loadtxt("../MMD/s3_mapped2.txt")
type1 = np.loadtxt("../MMD/s3_type1.txt")
type2 = np.loadtxt("../MMD/s3_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[100/2000] err:12.7988 alpha:0.6167
# epoch:[200/2000] err:6.7957 alpha:0.3453
# epoch:[300/2000] err:5.7013 alpha:0.4095
# epoch:[400/2000] err:3.5859 alpha:0.5071
# epoch:[500/2000] err:2.5772 alpha:0.5590
# epoch:[600/2000] err:2.2206 alpha:0.5847
# epoch:[700/2000] err:2.0652 alpha:0.5982
# epoch:[800/2000] err:1.9311 alpha:0.6072
# epoch:[900/2000] err:1.7846 alpha:0.6146
# epoch:[1000/2000] err:1.6932 alpha:0.6210
# epoch:[1100/2000] err:1.6541 alpha:0.6263
# epoch:[1200/2000] err:1.6349 alpha:0.6308
# epoch:[1300/2000] err:1.6223 alpha:0.6348
# epoch:[1400/2000] err:1.6123 alpha:0.6383
# epoch:[1500/2000] err:1.6031 alpha:0.6414
# epoch:[1600/2000] err:1.5932 alpha:0.6442
# epoch:[1700/2000] err:1.5825 alpha:0.6468
# epoch:[1800/2000] err:1.5714 alpha:0.6491
# epoch:[1900/2000] err:1.5604 alpha:0.6512
# epoch:[2000/2000] err:1.5504 alpha:0.6531
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:0.889820, align_loss:0.090517
# epoch:[20/100]: loss:0.783163, align_loss:0.083529
# epoch:[30/100]: loss:0.772941, align_loss:0.088227
# epoch:[40/100]: loss:0.679908, align_loss:0.083119
# epoch:[50/100]: loss:0.727921, align_loss:0.079448
# epoch:[60/100]: loss:0.763530, align_loss:0.085858
# epoch:[70/100]: loss:0.670336, align_loss:0.085679
# epoch:[80/100]: loss:0.619211, align_loss:0.084026
# epoch:[90/100]: loss:0.646137, align_loss:0.086876
# epoch:[100/100]: loss:0.625575, align_loss:0.083713
# Done
# ---------------------------------
# unionCom Done!
# time: 9.844946384429932 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# label transfer accuracy of data1:
# 0.9433333333333334
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
