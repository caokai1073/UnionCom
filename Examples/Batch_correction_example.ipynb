# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate scGEM data by UnionCom
data1 = np.loadtxt("./hsc/domain1.txt")
data2 = np.loadtxt("./hsc/domain2.txt")

integrated_data = UnionCom.fit_transform([data1, data2], distance='euclidean')
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (498, 1446)
# Dataset 1: (524, 1446)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:2.2994 alpha:1.0546
# epoch:[2000/20000] err:1.8796 alpha:1.0611
# epoch:[3000/20000] err:1.5968 alpha:1.0682
# epoch:[4000/20000] err:1.4631 alpha:1.0728
# epoch:[5000/20000] err:1.4006 alpha:1.0760
# epoch:[6000/20000] err:1.3534 alpha:1.0786
# epoch:[7000/20000] err:1.3054 alpha:1.0809
# epoch:[8000/20000] err:1.2658 alpha:1.0828
# epoch:[9000/20000] err:1.2348 alpha:1.0846
# epoch:[10000/20000] err:1.2091 alpha:1.0861
# epoch:[11000/20000] err:1.2993 alpha:1.1009
# epoch:[12000/20000] err:1.1992 alpha:1.0880
# epoch:[13000/20000] err:1.1734 alpha:1.0892
# epoch:[14000/20000] err:1.1935 alpha:1.0924
# epoch:[15000/20000] err:1.1581 alpha:1.0907
# epoch:[16000/20000] err:1.1944 alpha:1.0965
# epoch:[17000/20000] err:1.1479 alpha:1.0919
# ...

# %%
# test label transfer accuracy
type1 = np.loadtxt("./hsc/type1.txt")
type2 = np.loadtxt("./hsc/type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])
# Out:
# label transfer accuracy of data1:
# 0.8413654618473896

# %%
# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
