# %%
from unioncom import UnionCom
import numpy as np

# %%
data1 = np.loadtxt("../simu2/domain1.txt")
data2 = np.loadtxt("../simu2/domain2.txt")
type1 = np.loadtxt("../simu2/type1.txt")
type2 = np.loadtxt("../simu2/type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)

# %%
uc = UnionCom.UnionCom()
integrated_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (200, 1000)
# Dataset 1: (250, 500)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[100/2000] err:1.9735 alpha:1.2674
# epoch:[200/2000] err:1.7647 alpha:1.3223
# epoch:[300/2000] err:1.5465 alpha:1.4098
# epoch:[400/2000] err:1.2644 alpha:1.5184
# epoch:[500/2000] err:1.0498 alpha:1.6031
# epoch:[600/2000] err:0.9222 alpha:1.6583
# epoch:[700/2000] err:0.8426 alpha:1.6962
# epoch:[800/2000] err:0.7863 alpha:1.7250
# epoch:[900/2000] err:0.7422 alpha:1.7487
# epoch:[1000/2000] err:0.7059 alpha:1.7692
# epoch:[1100/2000] err:0.6757 alpha:1.7873
# epoch:[1200/2000] err:0.6498 alpha:1.8033
# epoch:[1300/2000] err:0.6265 alpha:1.8178
# epoch:[1400/2000] err:0.6050 alpha:1.8309
# epoch:[1500/2000] err:0.5854 alpha:1.8428
# epoch:[1600/2000] err:0.5680 alpha:1.8537
# epoch:[1700/2000] err:0.5523 alpha:1.8636
# epoch:[1800/2000] err:0.5379 alpha:1.8728
# epoch:[1900/2000] err:0.5249 alpha:1.8814
# epoch:[2000/2000] err:0.5130 alpha:1.8894
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:0.586859, align_loss:0.035810
# epoch:[20/100]: loss:0.538469, align_loss:0.026469
# epoch:[30/100]: loss:0.467248, align_loss:0.033252
# epoch:[40/100]: loss:0.440292, align_loss:0.025216
# epoch:[50/100]: loss:0.505366, align_loss:0.042049
# epoch:[60/100]: loss:0.470162, align_loss:0.026681
# epoch:[70/100]: loss:0.425636, align_loss:0.018586
# epoch:[80/100]: loss:0.386718, align_loss:0.016934
# epoch:[90/100]: loss:0.449193, align_loss:0.023068
# epoch:[100/100]: loss:0.460974, align_loss:0.017497
# Done
# ---------------------------------
# unionCom Done!
# time: 6.76184868812561 seconds

# %%
uc.test_LabelTA(integrated_data, [type1,type2])
uc.Visualize([data1,data2], integrated_data, mode='PCA') # without datatype
uc.Visualize([data1,data2], integrated_data, [type1,type2], mode='PCA') # with datatype
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# label transfer accuracy of data1:
# 0.9
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
