# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate simulation 1 in MMD-MA paper by UnionCom
data1 = np.loadtxt("./MMD/s1_mapped1.txt")
data2 = np.loadtxt("./MMD/s1_mapped2.txt")

integrated_data = UnionCom.fit_transform([data1, data2])

# test label transfer accuracy
type1 = np.loadtxt("./MMD/s1_type1.txt")
type2 = np.loadtxt("./MMD/s1_type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:3.1091 alpha:0.6239
# epoch:[2000/20000] err:2.1241 alpha:0.6907
# epoch:[3000/20000] err:1.4319 alpha:0.7402
# epoch:[4000/20000] err:1.1562 alpha:0.7610
# epoch:[5000/20000] err:1.0398 alpha:0.7697
# epoch:[6000/20000] err:0.9694 alpha:0.7744
# epoch:[7000/20000] err:0.9224 alpha:0.7775
# epoch:[8000/20000] err:0.8934 alpha:0.7797
# epoch:[9000/20000] err:0.8750 alpha:0.7813
# epoch:[10000/20000] err:0.8626 alpha:0.7826
# epoch:[11000/20000] err:0.8579 alpha:0.7830
# epoch:[12000/20000] err:0.8565 alpha:0.7837
# epoch:[13000/20000] err:0.8582 alpha:0.7841
# epoch:[14000/20000] err:0.8574 alpha:0.7843
# epoch:[15000/20000] err:0.8574 alpha:0.7848
# epoch:[16000/20000] err:0.8577 alpha:0.7853
# epoch:[17000/20000] err:0.8579 alpha:0.7854
# epoch:[18000/20000] err:0.8582 alpha:0.7853
# epoch:[19000/20000] err:0.8583 alpha:0.7856
# epoch:[20000/20000] err:0.8588 alpha:0.7860
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:1.879290, align_loss:0.181918
# epoch:[100/200]: loss:1.836332, align_loss:0.213725
# epoch:[150/200]: loss:1.777724, align_loss:0.235758
# epoch:[200/200]: loss:1.675737, align_loss:0.193770
# Done
# ---------------------------------
# unionCom Done!
# time: 41.32718086242676 seconds
# label transfer accuracy of data1:
# 0.95
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.

# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate simulation 1 in MMD-MA paper by UnionCom with barycentric projection
data1 = np.loadtxt("./MMD/s1_mapped1.txt")
data2 = np.loadtxt("./MMD/s1_mapped2.txt")

integrated_data = UnionCom.fit_transform([data1, data2], project='barycentric', log_pd=10000)

# test label transfer accuracy
type1 = np.loadtxt("./MMD/s1_type1.txt")
type2 = np.loadtxt("./MMD/s1_type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[10000/20000] err:0.8626 alpha:0.7826
# epoch:[20000/20000] err:0.8588 alpha:0.7860
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# Done
# ---------------------------------
# unionCom Done!
# time: 18.537603616714478 seconds
# label transfer accuracy of data1:
# 0.93
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.

# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate simulation 2 in MMD-MA paper by UnionCom
data1 = np.loadtxt("./MMD/s2_mapped1.txt")
data2 = np.loadtxt("./MMD/s2_mapped2.txt")

integrated_data = UnionCom.fit_transform([data1, data2], log_pd=10000)

# test label transfer accuracy
type1 = np.loadtxt("./MMD/s2_type1.txt")
type2 = np.loadtxt("./MMD/s2_type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[10000/20000] err:0.2773 alpha:0.5936
# epoch:[20000/20000] err:0.2897 alpha:0.5943
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:1.528167, align_loss:0.109026
# epoch:[100/200]: loss:1.774405, align_loss:0.113304
# epoch:[150/200]: loss:1.507442, align_loss:0.202872
# epoch:[200/200]: loss:1.399276, align_loss:0.079073
# Done
# ---------------------------------
# unionCom Done!
# time: 39.69315552711487 seconds
# label transfer accuracy of data1:
# 0.9833333333333333
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.

# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate simulation 2 in MMD-MA paper by UnionCom with barycentric projection
data1 = np.loadtxt("./MMD/s2_mapped1.txt")
data2 = np.loadtxt("./MMD/s2_mapped2.txt")

integrated_data = UnionCom.fit_transform([data1, data2], project='barycentric', log_pd=10000)

# test label transfer accuracy
type1 = np.loadtxt("./MMD/s2_type1.txt")
type2 = np.loadtxt("./MMD/s2_type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[10000/20000] err:0.2773 alpha:0.5936
# epoch:[20000/20000] err:0.2897 alpha:0.5943
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# Done
# ---------------------------------
# unionCom Done!
# time: 18.977250814437866 seconds
# label transfer accuracy of data1:
# 0.9533333333333334
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.

# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate simulation 3 in MMD-MA paper by UnionCom
data1 = np.loadtxt("./MMD/s3_mapped1.txt")
data2 = np.loadtxt("./MMD/s3_mapped2.txt")

integrated_data = UnionCom.fit_transform([data1, data2], log_pd=10000)

# test label transfer accuracy
type1 = np.loadtxt("./MMD/s3_type1.txt")
type2 = np.loadtxt("./MMD/s3_type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[10000/20000] err:1.2901 alpha:0.6707
# epoch:[20000/20000] err:1.3421 alpha:0.6712
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:1.574762, align_loss:0.198313
# epoch:[100/200]: loss:1.865476, align_loss:0.335653
# epoch:[150/200]: loss:1.517094, align_loss:0.208799
# epoch:[200/200]: loss:1.495764, align_loss:0.267650
# Done
# ---------------------------------
# unionCom Done!
# time: 39.45868515968323 seconds
# label transfer accuracy of data1:
# 0.9433333333333334
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.

# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate simulation 3 in MMD-MA paper by UnionCom with barycentric projection
data1 = np.loadtxt("./MMD/s3_mapped1.txt")
data2 = np.loadtxt("./MMD/s3_mapped2.txt")

integrated_data = UnionCom.fit_transform([data1, data2], project='barycentric', log_pd=10000)

# test label transfer accuracy
type1 = np.loadtxt("./MMD/s3_type1.txt")
type2 = np.loadtxt("./MMD/s3_type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[10000/20000] err:1.2901 alpha:0.6707
# epoch:[20000/20000] err:1.3421 alpha:0.6712
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# Done
# ---------------------------------
# unionCom Done!
# time: 19.35468626022339 seconds
# label transfer accuracy of data1:
# 0.94
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
