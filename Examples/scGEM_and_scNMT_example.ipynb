# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate scGEM data by UnionCom
data1 = np.loadtxt("./scGEM/domain1.txt")
data2 = np.loadtxt("./scGEM/domain2.txt")

integrated_data = UnionCom.fit_transform([data1, data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (177, 34)
# Dataset 1: (177, 27)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[1000/20000] err:3.4413 alpha:1.1721
# epoch:[2000/20000] err:2.2187 alpha:1.3400
# epoch:[3000/20000] err:1.6585 alpha:1.4226
# epoch:[4000/20000] err:1.4607 alpha:1.4548
# epoch:[5000/20000] err:1.3754 alpha:1.4679
# epoch:[6000/20000] err:1.3278 alpha:1.4742
# epoch:[7000/20000] err:1.2977 alpha:1.4779
# epoch:[8000/20000] err:1.2784 alpha:1.4803
# epoch:[9000/20000] err:1.2660 alpha:1.4821
# epoch:[10000/20000] err:1.2588 alpha:1.4835
# epoch:[11000/20000] err:1.2550 alpha:1.4845
# epoch:[12000/20000] err:1.2538 alpha:1.4854
# epoch:[13000/20000] err:1.2594 alpha:1.4868
# epoch:[14000/20000] err:1.2573 alpha:1.4863
# epoch:[15000/20000] err:1.2587 alpha:1.4866
# epoch:[16000/20000] err:1.2614 alpha:1.4870
# epoch:[17000/20000] err:1.2636 alpha:1.4873
# epoch:[18000/20000] err:1.2661 alpha:1.4876
# epoch:[19000/20000] err:1.2680 alpha:1.4878
# epoch:[20000/20000] err:1.2704 alpha:1.4882
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:2.233330, align_loss:0.134530
# epoch:[100/200]: loss:1.974425, align_loss:0.127422
# epoch:[150/200]: loss:1.869382, align_loss:0.134517
# epoch:[200/200]: loss:1.931361, align_loss:0.121012
# Done
# ---------------------------------
# unionCom Done!
# time: 26.906709671020508 seconds

# %%
# test label transfer accuracy
type1 = np.loadtxt("./scGEM/type1.txt")
type2 = np.loadtxt("./scGEM/type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])
# Out:
# label transfer accuracy of data1:
# 0.615819209039548

# %%
# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.

# %%
# import unioncom and numpy
from unioncom import UnionCom
import numpy as np

# integrate scNMT data by UnionCom 
data1 = np.loadtxt("./scNMT/Eaccess.txt")
data2 = np.loadtxt("./scNMT/Emethy.txt")

integrated_data = UnionCom.fit_transform([data1, data2], epsilon=0.0001, log_pd=10000)

# test label transfer accuracy
type1 = np.loadtxt("./scNMT/type1.txt")
type2 = np.loadtxt("./scNMT/type2.txt")
UnionCom.test_label_transfer_accuracy(integrated_data, [type1,type2])

# visualization by PCA
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
UnionCom.PCA_visualize([data1,data2], integrated_data, [type1,type2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (612, 20)
# Dataset 1: (709, 20)
# ---------------------------------
# Find matching matrix between Dataset 1 and Dataset 2
# use device: cuda:0
# epoch:[10000/20000] err:0.3686 alpha:0.7516
# epoch:[20000/20000] err:0.2758 alpha:0.8090
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[50/200]: loss:1.983736, align_loss:0.181642
# epoch:[100/200]: loss:2.014482, align_loss:0.165908
# epoch:[150/200]: loss:1.887703, align_loss:0.166861
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# No handles with labels found to put in legend.
# epoch:[200/200]: loss:1.929339, align_loss:0.158469
# Done
# ---------------------------------
# unionCom Done!
# time: 72.40163612365723 seconds
# label transfer accuracy of data1:
# 0.9705882352941176
